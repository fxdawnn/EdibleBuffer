# %%
from osgeo import gdal
import rasterio
import os
import matplotlib.pyplot as plt
import numpy

# %%
import sys
sys.path.append( '../pymod' )

# %% [markdown]
# # Gdal reading landscape file

# %%
ds = gdal.Open('landscape_lcp/Landscape_1.lcp')

# %%
if ds.RasterCount != 8:
        gdaltest.post_reason('wrong number of bands')
        print('cool')

# %%
ds.RasterCount
# Out:
# 8

# %%
ds.GetProjectionRef().find('NAD_1983_UTM_Zone_12N')
# Out:
# -1

# %%
ds.GetProjectionRef()
# Out:
# 'PROJCS["USA_Contiguous_Albers_Equal_Area_Conic_USGS_version",GEOGCS["NAD83",DATUM["North_American_Datum_1983",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6269"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433]],PROJECTION["Albers_Conic_Equal_Area"],PARAMETER["latitude_of_center",23],PARAMETER["longitude_of_center",-96],PARAMETER["standard_parallel_1",29.5],PARAMETER["standard_parallel_2",45.5],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]'

# %%
testing = ds.GetGeoTransform()

# %%
md = ds.GetMetadata()

# %%
md
# Out:
# {'DESCRIPTION': '', 'LATITUDE': '38', 'LINEAR_UNIT': 'Meters'}

# %% [markdown]
# # Projection Handling for LCP file

# %%
new_gt = ds.GetGeoTransform()

# %%
new_gt
check_gt = (285807.932887174887583,30,0,5379230.386217921040952,0,-30)

# %%
for i in range(6):
        if abs(new_gt[i]-check_gt[i]) > 1e-5:
            print('')
            print('old = ', check_gt)
            print('new = ', new_gt)
# Out:
# old =  (285807.9328871749, 30, 0, 5379230.386217921, 0, -30)
# new =  (-2293725.0, 30.0, 0.0, 2062245.0, 0.0, -30.0)
#
# old =  (285807.9328871749, 30, 0, 5379230.386217921, 0, -30)
# new =  (-2293725.0, 30.0, 0.0, 2062245.0, 0.0, -30.0)

# %% [markdown]
# # Testing Raster Band Material

# %%
dataPerBand = [ ( 18645, [  ('ELEVATION_UNIT', '0' ),
                                ('ELEVATION_UNIT_NAME', 'Meters' ),
                                ('ELEVATION_MIN', '1064' ),
                                ('ELEVATION_MAX', '1492' ),
                                ('ELEVATION_NUM_CLASSES', '-1' ),
                                ('ELEVATION_FILE', '' ) ] ),
                    ( 16431, [  ('SLOPE_UNIT', '0' ),
                                ('SLOPE_UNIT_NAME', 'Degrees' ),
                                ('SLOPE_MIN', '0' ),
                                ('SLOPE_MAX', '34' ),
                                ('SLOPE_NUM_CLASSES', '36' ),
                                ('SLOPE_FILE', 'slope.asc' ) ] ),
                    ( 18851, [  ('ASPECT_UNIT', '2' ),
                                ('ASPECT_UNIT_NAME', 'Azimuth degrees' ),
                                ('ASPECT_MIN', '0' ),
                                ('ASPECT_MAX', '357' ),
                                ('ASPECT_NUM_CLASSES', '-1' ),
                                ('ASPECT_FILE', 'aspect.asc' ) ] ),
                    ( 26182, [  ('FUEL_MODEL_OPTION', '0' ),
                                ('FUEL_MODEL_OPTION_DESC', 'no custom models AND no conversion file needed' ),
                                ('FUEL_MODEL_MIN', '1' ),
                                ('FUEL_MODEL_MAX', '99' ),
                                ('FUEL_MODEL_NUM_CLASSES', '6' ),
                                ('FUEL_MODEL_VALUES', '1,2,5,8,10,99' ),
                                ('FUEL_MODEL_FILE', 'fbfm13.asc' ) ] ),
                    ( 30038, [  ('CANOPY_COV_UNIT', '0' ),
                                ('CANOPY_COV_UNIT_NAME', 'Categories (0-4)' ),
                                ('CANOPY_COV_MIN', '0' ),
                                ('CANOPY_COV_MAX', '95' ),
                                ('CANOPY_COV_NUM_CLASSES', '10' ),
                                ('CANOPY_COV_FILE', 'cancov.asc' ) ] ),
                    ( 22077, [  ('CANOPY_HT_UNIT', '3' ),
                                ('CANOPY_HT_UNIT_NAME', 'Meters x 10' ),
                                ('CANOPY_HT_MIN', '0' ),
                                ('CANOPY_HT_MAX', '375' ),
                                ('CANOPY_HT_NUM_CLASSES', '5' ),
                                ('CANOPY_HT_FILE', 'canht.asc' ) ] ),
                    ( 30388, [  ('CBH_UNIT', '3' ),
                                ('CBH_UNIT_NAME', 'Meters x 10' ),
                                ('CBH_MIN', '0' ),
                                ('CBH_MAX', '100' ),
                                ('CBH_NUM_CLASSES', '33' ),
                                ('CBH_FILE', 'cbh.asc' ) ] ),
                    ( 23249, [  ('CBD_UNIT', '3' ),
                                ('CBD_UNIT_NAME', 'kg/m^3 x 100' ),
                                ('CBD_MIN', '0' ),
                                ('CBD_MAX', '21' ),
                                ('CBD_NUM_CLASSES', '20' ),
                                ('CBD_FILE', 'cbd.asc' ) ] )
                  ]

# %%
raster = ds.GetRasterBand(1)

# %%
raster
# Out:
# <osgeo.gdal.Band; proxy of <Swig Object of type 'GDALRasterBandShadow *' at 0x7f9acfe21930> >

# %%
import numpy as np

# %%
ds.GetRasterBand(4).ReadAsArray()
# Out:
# array([[165, 165, 165, ..., 147, 147, 147],
#        [165, 165, 165, ..., 147, 102, 102],
#        [165, 165, 165, ..., 102, 102, 102],
#        ...,
#        [165, 165, 165, ..., 165, 165, 122],
#        [165, 165, 165, ..., 165, 165, 163],
#        [165, 165, 165, ..., 189, 189, 165]], dtype=int16)

# %%
myarray = np.array(ds.GetRasterBand(4).ReadAsArray())

# %%
myarray
# Out:
# array([[165, 165, 165, ..., 147, 147, 147],
#        [165, 165, 165, ..., 147, 102, 102],
#        [165, 165, 165, ..., 102, 102, 102],
#        ...,
#        [165, 165, 165, ..., 165, 165, 122],
#        [165, 165, 165, ..., 165, 165, 163],
#        [165, 165, 165, ..., 189, 189, 165]], dtype=int16)

# %% [markdown]
# - show that the change of fuel won't influence the work flow

# %%
np.where(myarray == 181)
# Out:
# (array([  0,   4,   6, 224]), array([1108, 1111, 1112,    4]))

# %%
myarray.shape
# Out:
# (1124, 1209)

# %%
myarray.shape[0]
# Out:
# 1124

# %%
myarray[0][0] = 0

# %% [markdown]
# # Define Driver type

# %%
mem_drv = gdal.GetDriverByName('MEM')

# %%
lcp_drv = gdal.GetDriverByName('LCP')

# %% [markdown]
# # Raster data Creation testing

# %%
import random
import struct
import numpy
from osgeo import osr
import matplotlib.pyplot as plt

# %%
src_ds = mem_drv.Create('/vsimem2/', myarray.shape[1], myarray.shape[0], 8, gdal.GDT_Int16)

# %%
data = [98 for i in range(myarray.size)]
struct.pack('h'*myarray.size, *myarray.flatten().tolist()) == myarray.tobytes()
# Out:
# True

# %%
data = [random.randint(0, 100) for i in range(myarray.size)]
src_ds.GetRasterBand(4).WriteRaster(0, 0, myarray.shape[1], myarray.shape[0], myarray.tobytes())
# Out:
# 0

# %% [markdown]
# - change raster in the buffer shape area to designated target_value

# %%
import gdal as gd
import ogr, osr

def zonal_buffer(rasters, buffer, target_value):
    #Open landscape raster data which is lcp
    rasters = gd.Open(rasters)
    
    #Open buffer data that is a shape file
    driver = ogr.GetDriverByName('ESRI Shapefile')
    shp = driver.Open(buffer)
    lyr = shp.GetLayer()
    
    # get raster georeference info
    transform = rasters.GetGeoTransform()
    xOrigin = transform[0]
    yOrigin = transform[3]
    pixelWidth = transform[1]
    pixelHeight = transform[5]
    
    # reproject geometry to same projection as raster
    sourceSR = lyr.GetSpatialRef()
    targetSR = osr.SpatialReference()
    targetSR.ImportFromWkt(rasters.GetProjectionRef())
    coordTrans = osr.CoordinateTransformation(sourceSR,targetSR)
    feat = lyr.GetNextFeature()
    geom = feat.GetGeometryRef()
    geom.Transform(coordTrans)
    
    # Get extent of geometry
    ring = geom.GetGeometryRef(0)
    numpoints = ring.GetPointCount()
    pointsX = []; pointsY = []
    for p in range(numpoints):
            lon, lat, z = ring.GetPoint(p)
            pointsX.append(lon)
            pointsY.append(lat)
    xmin = min(pointsX)
    xmax = max(pointsX)
    ymin = min(pointsY)
    ymax = max(pointsY)
   
    # Specify offset and rows and columns to read
    xoff = int((xmin - xOrigin)/pixelWidth)
    yoff = int((yOrigin - ymax)/pixelWidth)
    xcount = int((xmax - xmin)/pixelWidth)+1
    ycount = int((ymax - ymin)/pixelWidth)+1
    
    # get the fuel model
    banddataraster = rasters.GetRasterBand(4).ReadAsArray().astype(numpy.float)
    
    # create memory target raster
    target_ds = gdal.GetDriverByName('MEM').Create('', banddataraster.shape[1], banddataraster.shape[0], gdal.GDT_Byte)
    target_ds.SetGeoTransform(transform)
    
    # create for target raster the same projection as for the value raster
    raster_srs = osr.SpatialReference()
    raster_srs.ImportFromWkt(rasters.GetProjectionRef())
    target_ds.SetProjection(raster_srs.ExportToWkt())
    # rasterize zone polygon to raster
    gdal.RasterizeLayer(target_ds, [1], lyr, burn_values=[1])
    
    # read raster as arrays
    banddataraster = rasters.GetRasterBand(4)
    dataraster = banddataraster.ReadAsArray()

    bandmask = target_ds.GetRasterBand(1)
    datamask = bandmask.ReadAsArray()
    
    #show the layer
    dataraster[datamask>0] = target_value

    plt.imshow(dataraster)
    plt.colorbar()
    plt.title('Overview - Band 4 {}'.format(dataraster.shape))
    plt.xlabel('Column #')
    plt.ylabel('Row #')
    
    return dataraster

# %% [markdown]
# - get summary data of the burn area

# %%
import gdal as gd
import ogr, osr

def fire_area(rasters, buffer):
    #Open landscape raster data which is lcp
    rasters = gd.Open(rasters)
    
    #Open buffer data that is a shape file
    driver = ogr.GetDriverByName('ESRI Shapefile')
    shp = driver.Open(buffer)
    lyr = shp.GetLayer()
    
    # get raster georeference info
    transform = rasters.GetGeoTransform()
    xOrigin = transform[0]
    yOrigin = transform[3]
    pixelWidth = transform[1]
    pixelHeight = transform[5]
    
    # reproject geometry to same projection as raster
    sourceSR = lyr.GetSpatialRef()
    targetSR = osr.SpatialReference()
    targetSR.ImportFromWkt(rasters.GetProjectionRef())
    coordTrans = osr.CoordinateTransformation(sourceSR,targetSR)
    feat = lyr.GetNextFeature()
    geom = feat.GetGeometryRef()
    geom.Transform(coordTrans)
    
    # Get extent of geometry
    ring = geom.GetGeometryRef(0)
    numpoints = ring.GetPointCount()
    pointsX = []; pointsY = []
    for p in range(numpoints):
            lon, lat, z = ring.GetPoint(p)
            pointsX.append(lon)
            pointsY.append(lat)
    xmin = min(pointsX)
    xmax = max(pointsX)
    ymin = min(pointsY)
    ymax = max(pointsY)
   
    # Specify offset and rows and columns to read
    xoff = int((xmin - xOrigin)/pixelWidth)
    yoff = int((yOrigin - ymax)/pixelWidth)
    xcount = int((xmax - xmin)/pixelWidth)+1
    ycount = int((ymax - ymin)/pixelWidth)+1
    
    # get the fuel model
    banddataraster = rasters.GetRasterBand(4).ReadAsArray().astype(numpy.float)
    
    # create memory target raster
    target_ds = gdal.GetDriverByName('MEM').Create('', banddataraster.shape[1], banddataraster.shape[0], gdal.GDT_Byte)
    target_ds.SetGeoTransform(transform)
    
    # create for target raster the same projection as for the value raster
    raster_srs = osr.SpatialReference()
    raster_srs.ImportFromWkt(rasters.GetProjectionRef())
    target_ds.SetProjection(raster_srs.ExportToWkt())
    # rasterize zone polygon to raster
    gdal.RasterizeLayer(target_ds, [1], lyr, burn_values=[1])
    
    # read raster as arrays
    banddataraster = rasters.GetRasterBand(4)
    dataraster = banddataraster.ReadAsArray()

    bandmask = target_ds.GetRasterBand(1)
    datamask = bandmask.ReadAsArray()
    
    #show the layer
    dataraster[datamask==0] = 0

    plt.imshow(dataraster)
    plt.colorbar()
    plt.title('Overview - Band 4 {}'.format(dataraster.shape))
    plt.xlabel('Column #')
    plt.ylabel('Row #')
    
    return dataraster

# %%
import matplotlib.pyplot as plt
satellite_fire_area = fire_area("landscape_lcp/Landscape_1.lcp", "Tubbs Fire Satellite Data/ca_tubbs_20171010_2344_dd83.shp")

# %%
satellite_value = satellite_fire_area.flatten()
satellite_value = satellite_value[satellite_value!=0]
d = np.diff(np.unique(satellite_value)).min()
left_of_first_bin = satellite_value.min() - float(d)/2
right_of_last_bin = satellite_value.max() + float(d)/2
plt.hist(satellite_value, np.arange(left_of_first_bin, right_of_last_bin + d, d))
plt.show()

# %%
import geopandas as gpd
buffer_1_gpd = gpd.read_file("Urban_shape/Tubbs_urban_to_TL1_1600_1010.shp")
buffer_1_gpd.plot()

# %%
satellite_fire_area = fire_area("landscape_lcp/Landscape_1.lcp", "Tubbs Fire Satellite Data/ca_tubbs_20171010_1600_dd83.shp")

# %%
len(np.where(satellite_fire_area==93)[0])
# Out:
# 5047

# %%
satellite_value = satellite_fire_area.flatten()

# %%
satellite_value = satellite_value[satellite_value!=0]

# %%
satellite_value
# Out:
# array([165, 184, 142, ..., 101,  91,  91], dtype=int16)

# %%
len(satellite_value)
# Out:
# 119819

# %%
fuel_occurance = np.count_nonzero(satellite_value == 91)
fuel_occurance
# Out:
# 15893

# %%
unique_satellite_value = np.unique(satellite_value)

# %%
unique_satellite_value
# Out:
# array([ 91,  93,  98,  99, 101, 102, 103, 121, 122, 142, 145, 147, 162,
#        163, 165, 182, 183, 184, 185, 186, 188, 189, 202], dtype=int16)

# %%
d = np.diff(np.unique(satellite_value)).min()
left_of_first_bin = satellite_value.min() - float(d)/2
right_of_last_bin = satellite_value.max() + float(d)/2
plt.hist(satellite_value, np.arange(left_of_first_bin, right_of_last_bin + d, d))
plt.show()

# %%
len(unique_satellite_value)
# Out:
# 23

# %%
fuel_occurance
# Out:
# 15893

# %%
len(np.where(satellite_fire_area==91)[0])
# Out:
# 15893

# %%
len(np.where(satellite_fire_area==182)[0])
# Out:
# 2318

# %%
fire_fuel_histogram = np.histogram(satellite_value)
plt.hist(fire_fuel_histogram, bins=1)
plt.show()

# %%
len(np.where(satellite_fire_area>0)[0])
# Out:
# 119819

# %%
len(np.where(satellite_fire_area==93)[0])/len(np.where(satellite_fire_area>0)[0])
# Out:
# 0.04212186714961734

# %% [markdown]
# - Set Projection

# %%
prj = ds.GetProjectionRef()
prj
# Out:
# 'PROJCS["USA_Contiguous_Albers_Equal_Area_Conic_USGS_version",GEOGCS["NAD83",DATUM["North_American_Datum_1983",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6269"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433]],PROJECTION["Albers_Conic_Equal_Area"],PARAMETER["latitude_of_center",23],PARAMETER["longitude_of_center",-96],PARAMETER["standard_parallel_1",29.5],PARAMETER["standard_parallel_2",45.5],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]'

# %%
sr = osr.SpatialReference()
sr.SetProjection ("NAD83")
sr_wkt = sr.ExportToWkt()
print(sr_wkt)
# Out:
# PROJCS["unnamed",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["NAD83"],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]

# %%
new_prj = src_ds.SetProjection(prj)

# %% [markdown]
# - Create new lcp adapter

# %%
for i in range(8):
    #data = [random.randint(0, 100) for i in range(myarray.size)]
    myarray = ds.GetRasterBand(i+1).ReadAsArray()
    src_ds.GetRasterBand(i+1).WriteRaster(0, 0, myarray.shape[1], myarray.shape[0], myarray.tobytes())

# %%
src_ds.SetGeoTransform([-2293725.0, 30.0, 0.0, 2062245.0, 0.0, -30.0])
src_ds.GetGeoTransform()
# Out:
# (-2293725.0, 30.0, 0.0, 2062245.0, 0.0, -30.0)

# %% [markdown]
# # Testing the urban burnt

# %%
fuel_model_layer = np.array(ds.GetRasterBand(4).ReadAsArray())
plt.imshow(fuel_model_layer)
plt.colorbar()
plt.title('Overview - Band 4 {}'.format(fuel_model_layer.shape))
plt.xlabel('Column #')
plt.ylabel('Row #')
# Out:
# Text(0, 0.5, 'Row #')

# %% [markdown]
# - Change the buffer to non-permeable and urban to TL2

# %%
# place buffer the intput value are 181 for TL1 to banana and 93 for Agriculture
# Buffer option depends on the experiment
buffer_landscape = zonal_buffer('landscape_lcp/Landscape_1.lcp', "testing_buffer/buffer_polygon_standard_1.shp", 2)
#change the urban land to TL2
buffer_landscape[buffer_landscape == 91] = 182
plt.imshow(buffer_landscape)
plt.colorbar()
plt.title('Overview - Band 4 {}'.format(buffer_landscape.shape))
plt.xlabel('Column #')
plt.ylabel('Row #')
# Out:
# Text(0, 0.5, 'Row #')

# %% [markdown]
# - Output the landscape to lcp file

# %%
src_ds.GetRasterBand(4).WriteRaster(0, 0, buffer_landscape.shape[1], buffer_landscape.shape[0], buffer_landscape.tobytes())
co = ['LATITUDE=38', 'LINEAR_UNIT=METER', "ELEVATION_UNIT=METERS", "SLOPE_UNIT=DEGREES", "ASPECT_UNIT=AZIMUTH_DEGREES",
      "CANOPY_COV_UNIT = Categories (0-4)", "CANOPY_HT_UNIT_NAME=Meters x 10", "CBH_UNIT_NAME=Meters x 10", "CBD_UNIT_NAME=kg/m^3 x 100"]
out_name = "633_buffer/633_fbfm2_vineyardbuffer/FMFB2_buffer633_urban_to_TL2.lcp"
lcp_ds = lcp_drv.CreateCopy(out_name, src_ds, False, co)
print("SUCCESS: " + out_name)
# Out:
# SUCCESS: 633_buffer/633_fbfm2_vineyardbuffer/FMFB2_buffer633_urban_to_TL2.lcp

# %%
# NB1(urban area) == 91, TL1 == 181
fuel_model_layer[fuel_model_layer == 91] = 182

# %%
plt.imshow(fuel_model_layer)
plt.colorbar()
plt.title('Overview - Band 4 {}'.format(fuel_model_layer.shape))
plt.xlabel('Column #')
plt.ylabel('Row #')
# Out:
# Text(0, 0.5, 'Row #')

# %%
src_ds.GetRasterBand(4).WriteRaster(0, 0, fuel_model_layer.shape[1], fuel_model_layer.shape[0], fuel_model_layer.tobytes())
co = ['LATITUDE=38', 'LINEAR_UNIT=METER', "ELEVATION_UNIT=METERS", "SLOPE_UNIT=DEGREES", "ASPECT_UNIT=AZIMUTH_DEGREES",
      "CANOPY_COV_UNIT = Categories (0-4)", "CANOPY_HT_UNIT_NAME=Meters x 10", "CBH_UNIT_NAME=Meters x 10", "CBD_UNIT_NAME=kg/m^3 x 100"]
lcp_ds = lcp_drv.CreateCopy("testing_fire_lcp_more/lcp_creation_testing_urban_to_TL2_0.lcp", src_ds, False, co)
print("SUCCESS: testing_fire_lcp_more/lcp_creation_testing_urban_to_TL2_0.lcp")
# Out:
# SUCCESS: testing_fire_lcp_more/lcp_creation_testing_urban_to_TL2_0.lcp

# %% [markdown]
# + Change fuel model

# %%
myarray = ds.GetRasterBand(4).ReadAsArray()
data = [98 for i in range(myarray.size)]
#struct.pack('h'*myarray.size, *data)
fm_change = zonal_buffer('landscape_lcp/Landscape_1.lcp', "buffer_3/tubbs_ember_buffer_testing_3.shp", 163)
source_fm = ds.GetRasterBand(4).ReadAsArray()
src_ds.GetRasterBand(4).WriteRaster(0, 0, fm_change.shape[1], fm_change.shape[0], fm_change.tobytes())
np.where(fm_change!= source_fm)[0].size
# Out:
# 811

# %%
number_choice = ["1", "2", "3"]
fuel_options = {"GR5":105, "GR7":107, "GS4": 124, "SH3": 143, "SH4":144,"SH6":146,"SH8":148}
fuel_values = [105, 107, 124, 143, 144, 146, 148]

for i in number_choice:
    print(i)
len(fuel_options)
for i in fuel_options:
    print(i, fuel_options[i])
name = "buffer_" + "1" + "/tubbs_ember_buffer_testing_" + "1" + ".shp"
fm_change = zonal_buffer('landscape_lcp/Landscape_1.lcp', name, fuel_options["GR5"])
# Out:
# 1
# 2
# 3
# GR5 105
# GR7 107
# GS4 124
# SH3 143
# SH4 144
# SH6 146
# SH8 148

# %%
number_choice = ["1", "2", "3"]
for number in number_choice:
    name = "buffer_" + number + "/tubbs_ember_buffer_testing_" + number + ".shp"
    fm_change = zonal_buffer('landscape_lcp/Landscape_1.lcp', name, 93)
    src_ds.GetRasterBand(4).WriteRaster(0, 0, fm_change.shape[1], fm_change.shape[0], fm_change.tobytes())
    co = ['LATITUDE=38', 'LINEAR_UNIT=METER', "ELEVATION_UNIT=METERS", "SLOPE_UNIT=DEGREES", "ASPECT_UNIT=AZIMUTH_DEGREES",
          "CANOPY_COV_UNIT = Categories (0-4)", "CANOPY_HT_UNIT_NAME=Meters x 10", "CBH_UNIT_NAME=Meters x 10", "CBD_UNIT_NAME=kg/m^3 x 100"]
    lcp_ds = lcp_drv.CreateCopy("testing_fire_lcp_more/lcp_creation_testing"+ "NB3" + "_change_buffer_" + number +".lcp", src_ds, False, co)
    print("SUCCESS: standard_all_buffer_tubbs/lcp_creation_testing"+ "NB3" + "_change_buffer_" + number +".lcp")
# Out:
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingNB3_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingNB3_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingNB3_change_buffer_3.lcp

# %% [markdown]
# # Fire Buffer Creation

# %%
import geopandas as gpd
buffer_1_big = gpd.read_file("testing_buffer/buffer_polygon_standard_1.shp")

# %%
buffer_1_big.plot()

# %%
name = "testing_buffer/buffer_polygon_standard_1.shp"
fm_change = zonal_buffer('landscape_lcp/Landscape_1.lcp', name, 181)

# %%
fuel_options = {"TL1": 181, "TL2": 182}
for fuel_type in fuel_options:
    for count in range(9):
        name = "testing_buffer/buffer_polygon_standard_"+ str(count) + ".shp"
        fm_change = zonal_buffer('landscape_lcp/Landscape_1.lcp', name, fuel_options[fuel_type])
        src_ds.GetRasterBand(4).WriteRaster(0, 0, fm_change.shape[1], fm_change.shape[0], fm_change.tobytes())
        co = ['LATITUDE=38', 'LINEAR_UNIT=METER', "ELEVATION_UNIT=METERS", "SLOPE_UNIT=DEGREES", "ASPECT_UNIT=AZIMUTH_DEGREES",
              "CANOPY_COV_UNIT = Categories (0-4)", "CANOPY_HT_UNIT_NAME=Meters x 10", "CBH_UNIT_NAME=Meters x 10", "CBD_UNIT_NAME=kg/m^3 x 100"]
        lcp_ds = lcp_drv.CreateCopy("FireUrbanBuffer/TL/lcp_urban_buffer_"+ fuel_type + "_change_buffer_" + str(count) +".lcp", src_ds, False, co)
        print("SUCCESS: sFireUrbanBuffer/TL/lcp_urban_buffer_"+ fuel_type + "_change_buffer_" + str(count) +".lcp")
# Out:
# SUCCESS: sFireUrbanBuffer/TL/lcp_urban_buffer_TL1_change_buffer_0.lcp
# SUCCESS: sFireUrbanBuffer/TL/lcp_urban_buffer_TL1_change_buffer_1.lcp
# SUCCESS: sFireUrbanBuffer/TL/lcp_urban_buffer_TL1_change_buffer_2.lcp
# SUCCESS: sFireUrbanBuffer/TL/lcp_urban_buffer_TL1_change_buffer_3.lcp
# SUCCESS: sFireUrbanBuffer/TL/lcp_urban_buffer_TL1_change_buffer_4.lcp
# SUCCESS: sFireUrbanBuffer/TL/lcp_urban_buffer_TL1_change_buffer_5.lcp
# SUCCESS: sFireUrbanBuffer/TL/lcp_urban_buffer_TL1_change_buffer_6.lcp
# SUCCESS: sFireUrbanBuffer/TL/lcp_urban_buffer_TL1_change_buffer_7.lcp
# SUCCESS: sFireUrbanBuffer/TL/lcp_urban_buffer_TL1_change_buffer_8.lcp
# SUCCESS: sFireUrbanBuffer/TL/lcp_urban_buffer_TL2_change_buffer_0.lcp
# SUCCESS: sFireUrbanBuffer/TL/lcp_urban_buffer_TL2_change_buffer_1.lcp
# SUCCESS: sFireUrbanBuffer/TL/lcp_urban_buffer_TL2_change_buffer_2.lcp
# SUCCESS: sFireUrbanBuffer/TL/lcp_urban_buffer_TL2_change_buffer_3.lcp
# SUCCESS: sFireUrbanBuffer/TL/lcp_urban_buffer_TL2_change_buffer_4.lcp
# SUCCESS: sFireUrbanBuffer/TL/lcp_urban_buffer_TL2_change_buffer_5.lcp
# SUCCESS: sFireUrbanBuffer/TL/lcp_urban_buffer_TL2_change_buffer_6.lcp
# SUCCESS: sFireUrbanBuffer/TL/lcp_urban_buffer_TL2_change_buffer_7.lcp
# SUCCESS: sFireUrbanBuffer/TL/lcp_urban_buffer_TL2_change_buffer_8.lcp

# %%
fuel_options = {"NB3": 93, "GR4":104, "GR8":108, "GS2": 122,"SB1": 201}
for fuel_type in fuel_options:
    for count in range(9):
        name = "testing_buffer/buffer_polygon_standard_"+ str(count) + ".shp"
        fm_change = zonal_buffer('landscape_lcp/Landscape_1.lcp', name, fuel_options[fuel_type])
        src_ds.GetRasterBand(4).WriteRaster(0, 0, fm_change.shape[1], fm_change.shape[0], fm_change.tobytes())
        co = ['LATITUDE=38', 'LINEAR_UNIT=METER', "ELEVATION_UNIT=METERS", "SLOPE_UNIT=DEGREES", "ASPECT_UNIT=AZIMUTH_DEGREES",
              "CANOPY_COV_UNIT = Categories (0-4)", "CANOPY_HT_UNIT_NAME=Meters x 10", "CBH_UNIT_NAME=Meters x 10", "CBD_UNIT_NAME=kg/m^3 x 100"]
        lcp_ds = lcp_drv.CreateCopy("FireUrbanBuffer/lcp_urban_buffer_"+ fuel_type + "_change_buffer_" + str(count) +".lcp", src_ds, False, co)
        print("SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_"+ fuel_type + "_change_buffer_" + str(count) +".lcp")
# Out:
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_NB3_change_buffer_0.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_NB3_change_buffer_1.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_NB3_change_buffer_2.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_NB3_change_buffer_3.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_NB3_change_buffer_4.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_NB3_change_buffer_5.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_NB3_change_buffer_6.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_NB3_change_buffer_7.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_NB3_change_buffer_8.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GR4_change_buffer_0.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GR4_change_buffer_1.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GR4_change_buffer_2.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GR4_change_buffer_3.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GR4_change_buffer_4.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GR4_change_buffer_5.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GR4_change_buffer_6.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GR4_change_buffer_7.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GR4_change_buffer_8.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GR8_change_buffer_0.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GR8_change_buffer_1.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GR8_change_buffer_2.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GR8_change_buffer_3.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GR8_change_buffer_4.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GR8_change_buffer_5.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GR8_change_buffer_6.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GR8_change_buffer_7.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GR8_change_buffer_8.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GS2_change_buffer_0.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GS2_change_buffer_1.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GS2_change_buffer_2.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GS2_change_buffer_3.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GS2_change_buffer_4.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GS2_change_buffer_5.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GS2_change_buffer_6.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GS2_change_buffer_7.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_GS2_change_buffer_8.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_SB1_change_buffer_0.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_SB1_change_buffer_1.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_SB1_change_buffer_2.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_SB1_change_buffer_3.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_SB1_change_buffer_4.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_SB1_change_buffer_5.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_SB1_change_buffer_6.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_SB1_change_buffer_7.lcp
# SUCCESS: sFireUrbanBuffer/lcp_urban_buffer_SB1_change_buffer_8.lcp

# %% [markdown]
# # Testing Fuel Model behavior

# %%
number_choice = ["1", "2", "3"]
fuel_options = {"NB5": 95, "NB7": 97, "NB9": 99, "GR1":101, "GR2":102, "GR3":103, "GR4":104, "GR5":105, 
                "GR6":106, "GR7":107, "GR8":108, "GR9":109, "GS1": 121, "GS2": 122,
                "GS3": 123,"GS4": 124, "SH1": 141, "SH2": 142, "SH3": 143, "SH4":144,
                "SH5": 145, "SH6":146, "SH7": 147, "SH8":148, "SH9": 149, "TU1": 161,
                "TU2":162, "TU3": 163, "TU4": 164, "TU5": 165, "TL1": 181, "TL2": 182,
                "TL3": 183, "TL4": 184, "TL5": 185, "TL6": 186, "TL7": 187, "TL8": 188,
                "TL9": 189, "SB1": 201, "SB2": 202, "SB3": 203, "SB4": 204}
fuel_values = [105, 107, 124, 143, 144, 146, 148]

for fuel_type in fuel_options:
    for number in number_choice:
        name = "buffer_" + number + "/tubbs_ember_buffer_testing_" + number + ".shp"
        fm_change = zonal_buffer('landscape_lcp/Landscape_1.lcp', name, fuel_options[fuel_type])
        src_ds.GetRasterBand(4).WriteRaster(0, 0, fm_change.shape[1], fm_change.shape[0], fm_change.tobytes())
        co = ['LATITUDE=38', 'LINEAR_UNIT=METER', "ELEVATION_UNIT=METERS", "SLOPE_UNIT=DEGREES", "ASPECT_UNIT=AZIMUTH_DEGREES",
              "CANOPY_COV_UNIT = Categories (0-4)", "CANOPY_HT_UNIT_NAME=Meters x 10", "CBH_UNIT_NAME=Meters x 10", "CBD_UNIT_NAME=kg/m^3 x 100"]
        lcp_ds = lcp_drv.CreateCopy("standard_all_buffer_tubbs/lcp_creation_testing"+ fuel_type + "_change_buffer_" + number +".lcp", src_ds, False, co)
        print("SUCCESS: standard_all_buffer_tubbs/lcp_creation_testing"+ fuel_type + "_change_buffer_" + number +".lcp")
# Out:
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingNB5_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingNB5_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingNB5_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingNB7_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingNB7_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingNB7_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingNB9_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingNB9_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingNB9_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR1_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR1_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR1_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR2_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR2_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR2_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR3_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR3_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR3_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR4_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR4_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR4_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR5_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR5_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR5_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR6_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR6_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR6_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR7_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR7_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR7_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR8_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR8_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR8_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR9_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR9_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGR9_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGS1_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGS1_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGS1_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGS2_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGS2_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGS2_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGS3_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGS3_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGS3_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGS4_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGS4_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingGS4_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH1_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH1_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH1_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH2_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH2_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH2_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH3_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH3_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH3_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH4_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH4_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH4_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH5_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH5_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH5_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH6_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH6_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH6_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH7_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH7_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH7_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH8_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH8_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH8_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH9_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH9_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSH9_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTU1_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTU1_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTU1_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTU2_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTU2_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTU2_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTU3_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTU3_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTU3_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTU4_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTU4_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTU4_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTU5_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTU5_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTU5_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL1_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL1_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL1_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL2_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL2_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL2_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL3_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL3_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL3_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL4_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL4_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL4_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL5_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL5_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL5_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL6_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL6_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL6_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL7_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL7_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL7_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL8_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL8_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL8_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL9_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL9_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingTL9_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSB1_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSB1_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSB1_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSB2_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSB2_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSB2_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSB3_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSB3_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSB3_change_buffer_3.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSB4_change_buffer_1.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSB4_change_buffer_2.lcp
# SUCCESS: standard_all_buffer_tubbs/lcp_creation_testingSB4_change_buffer_3.lcp

# %% [markdown]
# + Set all pixel in fuel model layer to water

# %%
#src_ds.GetRasterBand(4).WriteRaster(0, 0, myarray.shape[1], myarray.shape[0], struct.pack('h'*myarray.size, *data))
#src_ds.GetRasterBand(4).WriteRaster(0, 0, fm_change.shape[1], fm_change.shape[0], fm_change.tobytes())
#src_ds.GetRasterBand(4).WriteRaster(0, 0, source_fm.shape[1], source_fm.shape[0], source_fm.tobytes())

# %% [markdown]
# + Create new lcp

# %%
co = ['LATITUDE=38', 'LINEAR_UNIT=METER', "ELEVATION_UNIT=METERS", "SLOPE_UNIT=DEGREES", "ASPECT_UNIT=AZIMUTH_DEGREES",
      "CANOPY_COV_UNIT = Categories (0-4)", "CANOPY_HT_UNIT_NAME=Meters x 10", "CBH_UNIT_NAME=Meters x 10", "CBD_UNIT_NAME=kg/m^3 x 100"]
lcp_ds = lcp_drv.CreateCopy('buffer_modification_testing/lcp_creation_testing_TU3_change_buffer_3.lcp', src_ds, False, co)

# %%
dest_fm = lcp_ds.GetRasterBand(4).ReadAsArray()

# %%
np.where(dest_fm!= source_fm)[0].size
# Out:
# 864

# %% [markdown]
# - Test New raster

# %%
units = lcp_ds.GetRasterBand(8).GetMetadataItem("CBD_UNIT_NAME")
units
# Out:
# 'kg/m^3 x 100'

# %%
ds.GetMetadata()
# Out:
# {'DESCRIPTION': '', 'LATITUDE': '38', 'LINEAR_UNIT': 'Meters'}

# %%
lcp_ds.RasterCount == ds.RasterCount
# Out:
# True

# %%
units_0 = lcp_ds.GetRasterBand(2).GetMetadata()
units_0
# Out:
# {'SLOPE_FILE': '',
#  'SLOPE_MAX': '58',
#  'SLOPE_MIN': '0',
#  'SLOPE_NUM_CLASSES': '58',
#  'SLOPE_UNIT': '0',
#  'SLOPE_UNIT_NAME': 'Degrees'}

# %%
units = ds.GetRasterBand(2).GetMetadata()
units
# Out:
# {'SLOPE_FILE': 'D:\\scratch\\dist\\lf16285728\\us_200lcp40\\output\\rastert_slope_1.txt',
#  'SLOPE_MAX': '58',
#  'SLOPE_MIN': '0',
#  'SLOPE_NUM_CLASSES': '58',
#  'SLOPE_UNIT': '0',
#  'SLOPE_UNIT_NAME': 'Degrees'}

# %%
new_gt = ds.GetGeoTransform()
new_gt
# Out:
# (-2293725.0, 30.0, 0.0, 2062245.0, 0.0, -30.0)

# %%
if lcp_ds.GetGeoTransform() !=lcp_ds.GetGeoTransform():
    print("Set up Geo wrong")

# %%
for i in range(8):
    testing_raster = np.array(ds.GetRasterBand(i+1).ReadAsArray())
    get_raster = np.array(lcp_ds.GetRasterBand(i+1).ReadAsArray())
    if np.where (testing_raster != get_raster)[0].size > 0:
        print("error copying")
# Out:
# error copying

# %%
ds.GetProjectionRef()
# Out:
# 'PROJCS["USA_Contiguous_Albers_Equal_Area_Conic_USGS_version",GEOGCS["NAD83",DATUM["North_American_Datum_1983",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6269"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433]],PROJECTION["Albers_Conic_Equal_Area"],PARAMETER["latitude_of_center",23],PARAMETER["longitude_of_center",-96],PARAMETER["standard_parallel_1",29.5],PARAMETER["standard_parallel_2",45.5],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]'

# %% [markdown]
# # Raster Creation based on existing

# %%
ds = gd.Open('landscape_lcp/Landscape_1.lcp')

# %%
drv = gdal.GetDriverByName('LCP')
dst_ds = drv.CreateCopy("testing_copy.lcp", ds, strict=0)

# %% [markdown]
# # Raster Clipping

# %%
import ogr

# %%
buffer_1 = ogr.Open("buffer_1/tubbs_ember_buffer_testing_1.shp")

# %%
buffer_1_layer = buffer_1.GetLayer()

# %%
feature = buffer_1_layer.GetFeature(0)

# %%
vectorGeometry = feature.GetGeometryRef()

# %%
import rasterio

# %%
testing_lcp.overviews(1)
# Out:
# []

# %% [markdown]
# - Visualization of the raster

# %%
import matplotlib.pyplot as plt
myarray = np.array(ds.GetRasterBand(4).ReadAsArray())
myarray
plt.imshow(myarray)
plt.colorbar()
plt.title('Overview - Band 4 {}'.format(myarray.shape))
plt.xlabel('Column #')
plt.ylabel('Row #')
# Out:
# Text(0, 0.5, 'Row #')

# %%
import matplotlib.pyplot as plt
myarray = np.array(ds.GetRasterBand(1).ReadAsArray())
myarray
plt.imshow(myarray)
plt.colorbar()
plt.title('Overview - Band 1 {}'.format(myarray.shape))
plt.xlabel('Column #')
plt.ylabel('Row #')
# Out:
# Text(0, 0.5, 'Row #')

# %%
units = ds.GetRasterBand(2)

# %% [markdown]
# - Get raster data again

# %%
import gdal, ogr, osr, numpy

# %%
rasters = gd.Open('landscape_lcp/Landscape_1.lcp')

# %%
ds = gd.Open('landscape_lcp/Landscape_1.lcp')

# %%
fm_raster = ds.GetRasterBand(4)

# %%
gt = ds.GetGeoTransform()

# %%
import geopandas as gpd
buffer_1_gpd = gpd.read_file("200_buffer/TL2_200_buffer.shp")

# %%
buffer_1_gpd.plot()

# %%
driver = ogr.GetDriverByName('ESRI Shapefile')
shp = driver.Open("buffer_1/tubbs_ember_buffer_testing_1.shp")
lyr = shp.GetLayer()

# %%
# get raster georeference info
transform = rasters.GetGeoTransform()
xOrigin = transform[0]
yOrigin = transform[3]
pixelWidth = transform[1]
pixelHeight = transform[5]
transform
# Out:
# (-2293725.0, 30.0, 0.0, 2062245.0, 0.0, -30.0)

# %%
# reproject geometry to same projection as raster
sourceSR = lyr.GetSpatialRef()
targetSR = osr.SpatialReference()
targetSR.ImportFromWkt(rasters.GetProjectionRef())
coordTrans = osr.CoordinateTransformation(sourceSR,targetSR)
feat = lyr.GetNextFeature()
geom = feat.GetGeometryRef()
geom.Transform(coordTrans)
# Out:
# 0

# %%
# Get extent of geometry
ring = geom.GetGeometryRef(0)
numpoints = ring.GetPointCount()
pointsX = []; pointsY = []
for p in range(numpoints):
        lon, lat, z = ring.GetPoint(p)
        pointsX.append(lon)
        pointsY.append(lat)
xmin = min(pointsX)
xmax = max(pointsX)
ymin = min(pointsY)
ymax = max(pointsY)
xmin, xmax, ymin, ymax
# Out:
# (-2270560.338867186,
#  -2264891.4136352544,
#  2048996.573669431,
#  2052636.3179321259)

# %%
# Specify offset and rows and columns to read
xoff = int((xmin - xOrigin)/pixelWidth)
yoff = int((yOrigin - ymax)/pixelWidth)
xcount = int((xmax - xmin)/pixelWidth)+1
ycount = int((ymax - ymin)/pixelWidth)+1
xoff, yoff, xcount, ycount
# Out:
# (772, 320, 189, 122)

# %%
banddataraster = rasters.GetRasterBand(4).ReadAsArray().astype(numpy.float)
banddataraster.shape
# Out:
# (1124, 1209)

# %%
# create memory target raster
target_ds = gdal.GetDriverByName('MEM').Create('', banddataraster.shape[1], banddataraster.shape[0], gdal.GDT_Byte)
#target_ds.SetGeoTransform((
#    xmin, pixelWidth, 0,
#    ymax, 0, pixelHeight,
#))
target_ds.SetGeoTransform(transform)
# Out:
# 0

# %%
# create for target raster the same projection as for the value raster
raster_srs = osr.SpatialReference()
raster_srs.ImportFromWkt(rasters.GetProjectionRef())
target_ds.SetProjection(raster_srs.ExportToWkt())
# rasterize zone polygon to raster
gdal.RasterizeLayer(target_ds, [1], lyr, burn_values=[1])
# Out:
# 0

# %%
# read raster as arrays
banddataraster = rasters.GetRasterBand(4)
dataraster = banddataraster.ReadAsArray().astype(numpy.float)

bandmask = target_ds.GetRasterBand(1)
datamask = bandmask.ReadAsArray().astype(numpy.float)
datamask.shape, dataraster.shape
# Out:
# ((1124, 1209), (1124, 1209))

# %%
plt.imshow(datamask*98)
plt.colorbar()
plt.title('Overview - Band 4 {}'.format(datamask.shape))
plt.xlabel('Column #')
plt.ylabel('Row #')
# Out:
# Text(0, 0.5, 'Row #')

# %%
plt.imshow(dataraster)
plt.colorbar()
plt.title('Overview - Band 4 {}'.format(dataraster.shape))
plt.xlabel('Column #')
plt.ylabel('Row #')
# Out:
# Text(0, 0.5, 'Row #')

# %%
# zone of raster change
#zoneraster = np.ma.masked_array(dataraster,  datamask)
dataraster[datamask>0] = 98


plt.imshow(dataraster)
plt.colorbar()
plt.title('Overview - Band 4 {}'.format(zoneraster.shape))
plt.xlabel('Column #')
plt.ylabel('Row #')
# Out:
# Text(0, 0.5, 'Row #')

# %% [markdown]
# + whole part as a function

# %%
import gdal as gd
import ogr

def zonal_buffer(rasters, buffer, target_value):
    #Open landscape raster data which is lcp
    rasters = gd.Open(rasters)
    
    #Open buffer data that is a shape file
    driver = ogr.GetDriverByName('ESRI Shapefile')
    shp = driver.Open(buffer)
    lyr = shp.GetLayer()
    
    # get raster georeference info
    transform = rasters.GetGeoTransform()
    xOrigin = transform[0]
    yOrigin = transform[3]
    pixelWidth = transform[1]
    pixelHeight = transform[5]
    
    # reproject geometry to same projection as raster
    sourceSR = lyr.GetSpatialRef()
    targetSR = osr.SpatialReference()
    targetSR.ImportFromWkt(rasters.GetProjectionRef())
    coordTrans = osr.CoordinateTransformation(sourceSR,targetSR)
    feat = lyr.GetNextFeature()
    geom = feat.GetGeometryRef()
    geom.Transform(coordTrans)
    
    # Get extent of geometry
    ring = geom.GetGeometryRef(0)
    numpoints = ring.GetPointCount()
    pointsX = []; pointsY = []
    for p in range(numpoints):
            lon, lat, z = ring.GetPoint(p)
            pointsX.append(lon)
            pointsY.append(lat)
    xmin = min(pointsX)
    xmax = max(pointsX)
    ymin = min(pointsY)
    ymax = max(pointsY)
   
    # Specify offset and rows and columns to read
    xoff = int((xmin - xOrigin)/pixelWidth)
    yoff = int((yOrigin - ymax)/pixelWidth)
    xcount = int((xmax - xmin)/pixelWidth)+1
    ycount = int((ymax - ymin)/pixelWidth)+1
    
    # get the fuel model
    banddataraster = rasters.GetRasterBand(4).ReadAsArray().astype(numpy.float)
    
    # create memory target raster
    target_ds = gdal.GetDriverByName('MEM').Create('', banddataraster.shape[1], banddataraster.shape[0], gdal.GDT_Byte)
    target_ds.SetGeoTransform(transform)
    
    # create for target raster the same projection as for the value raster
    raster_srs = osr.SpatialReference()
    raster_srs.ImportFromWkt(rasters.GetProjectionRef())
    target_ds.SetProjection(raster_srs.ExportToWkt())
    # rasterize zone polygon to raster
    gdal.RasterizeLayer(target_ds, [1], lyr, burn_values=[1])
    
    # read raster as arrays
    banddataraster = rasters.GetRasterBand(4)
    dataraster = banddataraster.ReadAsArray()

    bandmask = target_ds.GetRasterBand(1)
    datamask = bandmask.ReadAsArray()
    
    #show the layer
    dataraster[datamask>0] = target_value

    plt.imshow(dataraster)
    plt.colorbar()
    plt.title('Overview - Band 4 {}'.format(dataraster.shape))
    plt.xlabel('Column #')
    plt.ylabel('Row #')
    
    return dataraster

# %%
dr = zonal_buffer('landscape_lcp/Landscape_1.lcp', "buffer_1/tubbs_ember_buffer_testing_1.shp", 98)

# %%
np.where(dr != dataraster)
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
zonal_stats('landscape_lcp/Landscape_1.lcp', "buffer_1/tubbs_ember_buffer_testing_1.shp")
# Out:
# 123.82384823848238

# %%
buffer_1_gpd.plot()

# %%
import ogr

# %%
source_ds = ogr.Open("buffer_1/tubbs_ember_buffer_testing_1.shp")
source_layer = source_ds.GetLayer()

# %%
pixelWidth = pixelHeight = 30 # depending how fine you want your raster
x_min, x_max, y_min, y_max = source_layer.GetExtent()
cols = int((x_max - x_min) / pixelHeight)
rows = int((y_max - y_min) / pixelWidth)

# %%
[x_min, x_max, y_min, y_max]
# Out:
# [-122.67220972877918,
#  -122.59848894247726,
#  38.598715885736766,
#  38.616459755533675]

# %%
cols,rows
# Out:
# (0, 0)

# %%
geo = source_layer.GetGeoTransform()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-299-be0b35df412d> in <module>
# ----> 1 geo = source_layer.GetGeoTransform()
#
# /opt/anaconda3/envs/gdal_vegetation_wildfire/lib/python3.8/site-packages/osgeo/ogr.py in <lambda>(self, name)
#    1240     for _s in [MajorObject]:
#    1241         __swig_getmethods__.update(getattr(_s, '__swig_getmethods__', {}))
# -> 1242     __getattr__ = lambda self, name: _swig_getattr(self, Layer, name)
#    1243
#    1244     def __init__(self, *args, **kwargs):
#
# /opt/anaconda3/envs/gdal_vegetation_wildfire/lib/python3.8/site-packages/osgeo/ogr.py in _swig_getattr(self, class_type, name)
#      72
#      73 def _swig_getattr(self, class_type, name):
# ---> 74     return _swig_getattr_nondynamic(self, class_type, name, 0)
#      75
#      76
#
# /opt/anaconda3/envs/gdal_vegetation_wildfire/lib/python3.8/site-packages/osgeo/ogr.py in _swig_getattr_nondynamic(self, class_type, name, static)
#      67         return method(self)
#      68     if (not static):
# ---> 69         return object.__getattr__(self, name)
#      70     else:
#      71         raise AttributeError(name)
#
# AttributeError: type object 'object' has no attribute '__getattr__'

# %%
buffer_point = []

# %%
from glob import glob
